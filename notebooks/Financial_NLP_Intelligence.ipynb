# %% [markdown]
# # Financial NLP Intelligence using DNN vs LSTM vs GRU
#
# ## Apeiron AI — Boundless Possibilities, Infinite Potential
#
# ---
#
# # 📘 Capstone Project Overview
#
# Welcome to the **Financial NLP Intelligence Deep Learning Capstone Project**.
#
# In this project, you will build a complete end-to-end Natural Language Processing (NLP) pipeline for financial sentiment analysis using:
#
# - Deep Neural Network (DNN)
# - Long Short-Term Memory (LSTM)
# - Gated Recurrent Unit (GRU)
#
# You will:
#
# ✅ Load and explore financial text data
# ✅ Clean and preprocess text
# ✅ Create TF-IDF features for DNN
# ✅ Create tokenized sequences for LSTM/GRU
# ✅ Train and compare multiple deep learning models
# ✅ Evaluate performance using NLP metrics
# ✅ Visualize results using charts and confusion matrices
# ✅ Save the best model for deployment
#
# ---
#
# # 🎯 Business Problem
#
# A financial analytics company wants to build an AI-powered sentiment intelligence platform capable of analyzing financial news headlines and predicting whether market sentiment is:
#
# - Positive
# - Negative
# - Neutral
#
# ---
#
# # 🧠 Key Learning Goals
#
# By completing this notebook, you will learn:
#
# - NLP preprocessing
# - Text tokenization
# - TF-IDF feature engineering
# - Word embeddings
# - Deep Neural Networks
# - Recurrent Neural Networks
# - LSTM and GRU architectures
# - Model evaluation and comparison
#
# ---
#
# # ⚠️ Before You Start
#
# 1. Upload data.csv
# 2. Install required libraries
# 3. Run all notebook cells in order

# %% [markdown]
# # STEP 1: Setup & Imports
#
#
# ## 🎯 Objective
#
# Import NLP, Deep Learning, and visualization libraries.
#
# ---
#
# ## 📌 What You Will Learn
#
# - How NLP workflows are structured
# - Why reproducibility matters
# - How TensorFlow is used for NLP projects
#
# ---
#
# ## Expected Output
#
# ```python
# TensorFlow Version: 2.x.x
# GPU Available (optional)
#
# Environment Ready
# ```

# %%
# ==========================================================
# STEP 1: Setup & Imports
# Financial NLP Intelligence using DNN vs LSTM vs GRU
# ==========================================================

# ======================
# Core Libraries
# ======================

import numpy as np
import pandas as pd

# ======================
# Visualization
# ======================

import matplotlib.pyplot as plt
import seaborn as sns

# ======================
# NLP Libraries
# ======================

import nltk
import re
import string

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# ======================
# Deep Learning
# ======================

import tensorflow as tf

from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import (
    Dense,
    Dropout,
    Embedding,
    LSTM,
    GRU
)

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras.utils import to_categorical

from tensorflow.keras.callbacks import (
    EarlyStopping,
    ModelCheckpoint
)

# ======================
# Machine Learning Utilities
# ======================

from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)

# ======================
# Model Saving
# ======================

import joblib
import json
import os

# ======================
# Miscellaneous
# ======================

import random
import warnings

warnings.filterwarnings("ignore")

# ==========================================================
# Download NLTK Resources
# ==========================================================

nltk.download("stopwords")
nltk.download("punkt")

# For newer NLTK versions
try:
    nltk.download("punkt_tab")
except:
    pass

# ==========================================================
# Set Random Seeds
# ==========================================================

SEED = 42

np.random.seed(SEED)

random.seed(SEED)

tf.random.set_seed(SEED)

# ==========================================================
# Configure Display Options
# ==========================================================

pd.set_option("display.max_colwidth", 200)

plt.style.use("default")

# ==========================================================
# Check TensorFlow Version
# ==========================================================

print("=" * 50)
print("TensorFlow Version:", tf.__version__)
print("=" * 50)

# ==========================================================
# GPU Check (Optional)
# ==========================================================

gpus = tf.config.list_physical_devices('GPU')

if len(gpus) > 0:
    print("GPU Available")
    print(gpus)
else:
    print("Running on CPU")

# ==========================================================
# Environment Ready
# ==========================================================

print("\nEnvironment Ready")

# %% [markdown]
# # STEP 2: Load & Explore Dataset
#
#
# ## 🎯 Objective
#
# Understand the dataset before modeling.
#
# ### Tasks
#
# - Load CSV
# - Inspect records
# - Examine sentiment distribution
# - Check missing values
#
# ### Expected Output
#
# ```python
# Positive xxxx
# Negative xxxx
# Neutral  xxxx
# ```

# %%
df = pd.read_csv("data.csv")

# %% [markdown]
# # STEP 3: Text Preprocessing
#
#
# ## 🎯 Objective
#
# Clean financial headlines.
#
# ### Preprocessing Steps
#
# - Lowercase conversion
# - Remove punctuation
# - Tokenization
# - Stopword removal
#
# ### Expected Output
#
# Cleaned financial text displayed successfully.
#
# 🧠 Consistent preprocessing improves model performance.

# %%
# text cleaning code

# %% [markdown]
# # STEP 4: TF-IDF and Sequence Preparation
#
#
# ## 🎯 Objective
#
# Prepare features for deep learning models.
#
# ### DNN Input
# - TF-IDF vectors
#
# ### LSTM/GRU Input
# - Tokenized sequences
# - Padding
# - Embedding layers
#
# ### Expected Output
#
# ```python
# TF-IDF Shape: (samples, features)
# Sequence Shape: (samples, max_length)
# ```

# %%
# feature preparation

# %% [markdown]
# # STEP 5: Train/Test Split
#
#
# ## 🎯 Objective
#
# Create training and testing datasets.
#
# ### Why This Matters
#
# Models must be evaluated on unseen data to estimate generalization performance.
#
# ### Expected Output
#
# ```python
# Training samples
# Testing samples
# ```

# %%
# split data

# %% [markdown]
# # STEP 6: Define Models
#
#
# ## 🎯 Objective
#
# Define three deep learning architectures.
#
# ### Models
#
# 1. DNN
# 2. LSTM
# 3. GRU
#
# ### Expected Output
#
# ```python
# DNN initialized
# LSTM initialized
# GRU initialized
# ```

# %%
# model definitions

# %% [markdown]
# # STEP 7: Train Models
#
#
# ## 🎯 Objective
#
# Train all models using the same dataset.
#
# ### Expected Output
#
# Training logs showing:
#
# - Loss
# - Accuracy
# - Validation Loss
# - Validation Accuracy
#
# 🧠 Monitor overfitting by comparing training and validation metrics.

# %%
# training code

# %% [markdown]
# # STEP 8: Evaluate Models
#
#
# ## 🎯 Objective
#
# Compare all models.
#
# ### Metrics
#
# - Accuracy
# - Precision
# - Recall
# - F1 Score
#
# ### Expected Output
#
# | Model | Accuracy | Precision | Recall | F1 |
# |---------|---------|---------|---------|---------|
# | DNN | xx | xx | xx | xx |
# | LSTM | xx | xx | xx | xx |
# | GRU | xx | xx | xx | xx |

# %%
# evaluation code

# %% [markdown]
# # STEP 9: Confusion Matrix Visualization
#
#
# ## 🎯 Objective
#
# Visualize classification performance.
#
# ### What the Confusion Matrix Shows
#
# - Correct predictions
# - Misclassifications
# - Difficult sentiment classes
#
# ### Expected Output
#
# Confusion matrix displayed successfully.

# %%
# confusion matrix

# %% [markdown]
# # STEP 10: Model Comparison Charts
#
#
# ## 🎯 Objective
#
# Compare model performance visually.
#
# ### Charts
#
# - Accuracy comparison
# - F1-score comparison
#
# ### Expected Output
#
# Bar charts displayed successfully.

# %%
# charts

# %% [markdown]
# # STEP 11: Test Custom Predictions
#
#
# ## 🎯 Objective
#
# Predict sentiment for new financial headlines.
#
# ### Example
#
# ```python
# Prediction: Positive
# ```

# %%
# prediction code

# %% [markdown]
# # STEP 12: Save Best Model for Deployment
#
#
# ## 🎯 Objective
#
# Save the best model and preprocessing components.
#
# ### Files
#
# - best_sentiment_model.h5
# - tokenizer.pkl
# - label_encoder.pkl
# - tfidf_vectorizer.pkl
#
# ### Expected Output
#
# ```python
# Model saved successfully.
# ```

# %%
# save model

# %% [markdown]
# # STEP 13: Summary & Key Takeaways
#
#
# ## 🎯 Objective
#
# Review final results.
#
# ### Summary Includes
#
# - Best-performing model
# - Accuracy comparison
# - F1 comparison
# - Deployment readiness
#
# ### Expected Output
#
# ```python
# Best Model: GRU
# Highest Accuracy: xx.xx
# Highest F1-Score: xx.xx
# ```

# %%
# summary
